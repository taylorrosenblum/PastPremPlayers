# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Get complete list of teams in premier league for a given year
#
# *   Get complete list of teams in PL for the given year using <https://www.footballsquads.co.uk/eng/YYYY-YYYY/faprem.htm>
#
# * NOTE: year must be 2017 or earlier (bug)

# %%
def get_teams(year):

  '''
  returns links to teams in PL that year
  Ex. ['faprem/arsenal.htm','faprem/avilla.htm',faprem/birmin.htm']
  '''

  teams = []

  # Parse the HTML with BeautifulSoup
  url = "https://www.footballsquads.co.uk/eng/{}-{}/faprem.htm".format(year,year+1)
  response = requests.get(url)
  soup = BeautifulSoup(response.content, 'html.parser')

  # Find all h5 elements and extract their links
  for h5 in soup.find_all('h5'):
      a_tag = h5.find('a')
      if a_tag:
          team = a_tag.get('href')
          teams.append(team.split('/')[-1])

  return teams

# %% [markdown]
# # Create a list of all players in the premier league for a given year
# *   Then, get full roster for given year for each team in PL using <https://www.footballsquads.co.uk/eng/YYYY-YYYY/faprem/TEAM.htm>

# %%
def get_roster(year, team_name):
  url = "https://www.footballsquads.co.uk/eng/{}-{}/faprem/{}".format(year,year+1,team_name)
  response = requests.get(url)
  html_content = response.content

  # Parse the HTML with BeautifulSoup
  soup = BeautifulSoup(html_content, 'html.parser')

  # Find all table rows (tr)
  rows = soup.find_all('tr')

  # Extract player names from the second <td> element in each row
  player_names = []
  for row in rows:
      columns = row.find_all('td')
      if len(columns) > 1:
          name = columns[1].get_text(strip=True)  # Get the name from the 2nd column (index 1)
          if (name and name != 'Name') :  # Avoid empty names
              player_names.append(name)

  return player_names

# %% [markdown]
# # Get current status of player from Wikipedia
#
# Example 1:
# ```
# # Scrape infobox from player's wikipedia page
# infobox = get_infobox_df("Cesc Fabregas")
#
# # review data infobox to determine players status
# status = still_playing(infobox)
#
# print(status)
# ```
# ```
# Player not playing, last played for Como in 2022–2023
# ```

# %%
def wiki_request(player_name):
    # Format the player name to match Wikipedia URLs (spaces replaced with underscores)
    player_name = player_name.replace(' ', '_')

    # Request the player's Wikipedia page
    url = f"https://en.wikipedia.org/wiki/{player_name}"
    response = requests.get(url)

    if response.status_code != 200:
        return False

    else:
        return response


def parse_infobox(response):
    # Parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    # Locate the infobox table (class "infobox infobox-table vcard")
    infobox = soup.find('table', {'class': 'infobox infobox-table vcard'})

    if infobox:
      # Define lists to store table data
      section_header = None
      rows_data = []

      # Loop through all rows in the infobox
      for row in infobox.find_all('tr'):
          # Check if the row is a section header
          header = row.find('th', {'class': 'infobox-header'})
          if header:
              section_header = header.get_text(strip=True)
              continue  # skip this row because it's just a header

          # Extract data from each row (th and td)
          columns = row.find_all(['th', 'td'])
          row_data = [section_header]  # start row data with the section header

          for col in columns:
              # Clean up the cell text and append to row_data
              row_data.append(col.get_text(strip=True))

          if len(row_data) > 1:
              rows_data.append(row_data)

      # Create a DataFrame with the extracted data
      df = pd.DataFrame(rows_data, columns=["Section", "Attribute", "Value","",""])
      print('Successfully parsed infobox')
      return True, df

    else:
      print("No infobox found")
      return False, None

def get_status(player_name):

  print('getting states for {}'.format(player_name))

  active = "n/a"
  fclub = "n/a"
  fyear = "n/a"

  response = wiki_request(player_name)

  if response:
    parse_success, df = parse_infobox(response)
    if parse_success:
      # attempt to filter infobox data to senior career only
      if "Senior career*" in df['Section'].values:
        sc = df[df['Section']=="Senior career*"]
        latest = sc.iloc[-1]

        # check if final entry in senior career table contains a "total" tally
        if latest['Attribute'] == 'Total':
          active = False
          fclub = sc.iloc[-2].Value
          fyear = sc.iloc[-2].Attribute
          print("Successfully retrieved status; Player not playing, last played for {} in {}".format(fclub, fyear))
        else:
          active = True
          fclub = "n/a"
          fyear = "n/a"
          cclub = sc.iloc[-1].Value
          print("Successfully retrieved status; Player still playing, currently playing for {}".format(cclub))

      else:
        print("ERROR; 'Senior Career' Data not present in inbox box data")
    else:
      print("ERROR; Could not parse infobox")
  else:
    print("ERROR; Could not retrieve Wikipedia page")

  return active, fyear, fclub

# %% [markdown]
# # Testing

# %%
year = 2011

# get all players
players = []
teams = get_teams(year)
print(teams)
for team in teams:
  players.extend(get_roster(year, team))

print(players)
# Out:
# ['arsenal.htm', 'avilla.htm', 'blackbrn.htm', 'bolton.htm', 'chelsea.htm', 'everton.htm', 'fulham.htm', 'liverpool.htm', 'mancity.htm', 'manutd.htm', 'newcas.htm', 'norwich.htm', 'qpr.htm', 'stoke.htm', 'sunder.htm', 'swansea.htm', 'tottenha.htm', 'wba.htm', 'wigan.htm', 'wolves.htm']
# ['Manuel Almunia', 'Abou Diaby', 'Bacary Sagna', 'Per Mertesacker', 'Thomas Vermaelen', 'Laurent Koscielny', 'Tomáš Rosický', 'Mikel Arteta', 'Park Chu-Young', 'Robin van Persie', 'André Santos', 'Wojciech Szczęsny', 'Theo Walcott', 'Alex Oxlade-Chamberlain', 'Aaron Ramsey', 'Alexandre Song', 'Sébastien Squillaci', 'Jack Wilshere', 'Johan Djourou', 'Łukasz Fabiański', 'Carl Jenkinson', 'Kouassi Gervais "Gervinho" Yao', 'Kieran Gibbs', 'Marouane Chamakh', 'Yossi Benayoun', 'Benik Afobe', 'Zak Ansah', 'George Brislen-Hall', 'Francis Coquelin', 'Craig Eastmond', 'Sead Hajrovic', 'Conor Henderson', 'Gavin Hoyte', 'Sean McDermott', 'Jernade Meade', 'Ignasi Miquel', 'Nigel Neita', 'Oğuzhan Özyakup', 'Nico Yennaris', 'Martin Angha', 'Kyle Ebecilio', 'Emiliano Martínez', 'Elton Monteiro', 'Josh Rees', 'James Shea', 'Cesc Fàbregas', 'Carlos Vela', 'Samir Nasri', 'Armand Traoré', 'Henri Lansbury', 'Gilles Sunu', 'Nicklas Bendtner', 'Emmanuel Frimpong', 'Vito Mannone', 'Luke Freeman', 'Chuks Aneke', 'Daniel Boateng', 'Sanchez Watt', 'Rhys Murphy', 'Ryo Miyaichi', 'Thierry Henry', 'Andrey Arshavin', 'Shay Given', 'Alan Hutton', 'Stephen Warnock', 'Richard Dunne', 'James Collins', 'Stephen Ireland', 'Jermaine Jenas', 'Darren Bent', "Charles N'Zogbia", 'Gabriel Agbonlahor', 'Marc Albrighton', 'Nathan Delfouneso', 'Fabian Delph', 'Emile Heskey', 'Stiliyan Petrov', 'Ciaran Clark', 'Brad Guzan', 'Carlos Cuéllar', '
# %%
2011_players = ['Manuel Almunia', 'Abou Diaby', 'Bacary Sagna', 'Per Mertesacker', 'Thomas Vermaelen', 'Laurent Koscielny', 'Tomáš Rosický', 'Mikel Arteta', 'Park Chu-Young', 'Robin van Persie', 'André Santos', 'Wojciech Szczęsny', 'Theo Walcott', 'Alex Oxlade-Chamberlain', 'Aaron Ramsey', 'Alexandre Song', 'Sébastien Squillaci', 'Jack Wilshere', 'Johan Djourou', 'Łukasz Fabiański', 'Carl Jenkinson', 'Kouassi Gervais "Gervinho" Yao', 'Kieran Gibbs', 'Marouane Chamakh', 'Yossi Benayoun', 'Benik Afobe', 'Zak Ansah', 'George Brislen-Hall', 'Francis Coquelin', 'Craig Eastmond', 'Sead Hajrovic', 'Conor Henderson', 'Gavin Hoyte', 'Sean McDermott', 'Jernade Meade', 'Ignasi Miquel', 'Nigel Neita', 'Oğuzhan Özyakup', 'Nico Yennaris', 'Martin Angha', 'Kyle Ebecilio', 'Emiliano Martínez', 'Elton Monteiro', 'Josh Rees', 'James Shea', 'Cesc Fàbregas', 'Carlos Vela', 'Samir Nasri', 'Armand Traoré', 'Henri Lansbury', 'Gilles Sunu', 'Nicklas Bendtner', 'Emmanuel Frimpong', 'Vito Mannone', 'Luke Freeman', 'Chuks Aneke', 'Daniel Boateng', 'Sanchez Watt', 'Rhys Murphy', 'Ryo Miyaichi', 'Thierry Henry', 'Andrey Arshavin', 'Shay Given', 'Alan Hutton', 'Stephen Warnock', 'Richard Dunne', 'James Collins', 'Stephen Ireland', 'Jermaine Jenas', 'Darren Bent', "Charles N'Zogbia", 'Gabriel Agbonlahor', 'Marc Albrighton', 'Nathan Delfouneso', 'Fabian Delph', 'Emile Heskey', 'Stiliyan Petrov', 'Ciaran Clark', 'Brad Guzan', 'Carlos Cuéllar', 'Barry Bannan', 'Andreas Weimann', 'Enda Stevens', 'Eric Lichaj', 'Chris Herd', 'Nathan Baker', 'Andy Marshall', 'Daniel Johnson', 'Graham Burke', 'Derrick Williams', 'Gary Gardner', 'Samir Carruthers', 'Jack Grealish', 'Luke Young', 'Jonathan Hogg', 'Jean II Makoun', 'Elliott Parish', 'Shane Lowry', 'Habib Beye', 'Robbie Keane', 'Paul Robinson', 'Michel Salgado', 'Martin Olsson', 'Gaël Givet', 'David Dunn', 'Anthony Modeste', 'Mauro Formica', 'Vince Grella', 'Morten Gamst Pedersen', 'Mark Bunn', 'Radosav Petrović', "Steven N'Zonzi", 'Scott Dann', 'Bradley Orr', 'Jordan Slew', 'Rubén Rochina', 'Marcus Olsson', 'Nick Blackman', 'Junior Hoilett', 'Yakubu Aiyegbeni', 'David Goodwillie', 'Hérold Goulon', 'Simon Vukčević', "Anthony O'Connor", 'Grant Hanley', 'Bruno Ribeiro', 'Josh Morris', 'Jake Kean', 'Jason Lowe', 'Amine Linganzi', 'Zac Aley', 'Myles Anderson', 'Adam Henley', 'Robbie Cotton', 'Raheem Hanley', 'Sebastian Usai', 'Brett Emerton', 'Jason Roberts',
', 'David Stockdale', 'Danny Murphy', 'Philippe Senderos', 'Marcel Gecov', 'Damien Duff', 'Bjørn Helge Riise', 'Aaron Hughes', 'Mahamadou Diarra', 'Dickson Etuhu', 'Kerim Frei', 'Csaba Somogyi', 'Clint Dempsey', 'Lauri Dalla Valle', 'Zdeněk Grygera', 'Matthew Briggs', 'Simon Davies', 'Mousa Dembélé', 'Alex Kačaniklić', 'Rafik Halliche', 'Tom Donegan', 'Buomesca Tué Na Bangna', 'Courtney Harris', 'Neil Etheridge', 'Stephen Arthurworrey', 'Alex Smith', 'Marcus Bettinelli', 'Marcello Trotta', 'Josh Pritchard', 'Jesse Joronen', 'Carlos Salcido', 'Keanu Marsh-Brown', 'Richard Peniket', 'Bobby Zamora', 'Brad Jones', 'Glen Johnson', 'José Enrique', 'Daniel Agger', 'Fábio Aurélio', 'Luis Suárez', 'Steven Gerrard', 'Andy Carroll', 'Maxi Rodríguez', 'Jordan Henderson', 'Sebastián Coates', 'Dirk Kuyt', 'Stewart Downing', 'Jay Spearing', 'Lucas Leiva', 'Jamie Carragher', 'Pepe Reina', 'Charlie Adam', 'Suso', 'Raheem Sterling', 'Doni', 'Jonjo Shelvey', 'Martin Kelly', 'Conor Coady', 'Nathan Eccleston', 'Martin Škrteľ', 'Jon Flanagan', 'Craig Bellamy', 'Péter Gulácsi', 'Andre Wisdom', 'Jack Robinson', 'Daniel Ayala', 'Sotirios Kyrgiakos', 'Daniel Pacheco', 'Alberto Aquilani', 'Joe Cole', 'Christian Poulsen', "David N'Gog", 'Raul Meireles', 'Danny Wilson', 'Martin Hansen', 'Micah Richards', 'Vincent Kompany', 'Pablo Zabaleta', 'Joleon Lescott', 'James Milner', 'David Pizarro', 'Edin Džeko', 'Adam Johnson', 'Stuart Taylor', 'Aleksandar Kolarov', 'Stefan Savić', 'Sergio Agüero', 'Gareth Barry', 'Samir Nasri', 'Owen Hargreaves', 'David Silva', 'Gaël Clichy', 'Joe Hart', 'Kolo Touré', 'Costel Pantilimon', 'Carlos Tévez', 'Nigel de Jong', 'Gai Assulin', 'Denis Suárez', 'Gunnar Nielsen', 'Yaya Touré', 'Karim Rekik', 'Mario Balotelli', 'Harry Bunn', 'Luca Scapuzzi', 'Sean Tse', 'Reece Wabara', 'Ahmad Benali', 'Jérémy Helan', 'Abdul Razak', 'Eirik Johansen', 'Joan Román', 'Emmanuel Adebayor', 'Dedryck Boyata', 'Roque Santa Cruz', 'Vladimir Weiss', 'Shaun Wright-Phillips', 'Craig Bellamy', 'Greg Cunningham', 'Kieran Trippier', 'Chris Chantler', 'Loris Karius', 'David González', 'Alex Nimely', 'Ben Mee', 'Andrea Mancini', 'Nedum Onuoha', 'Wayne Bridge', 'Frédéric Veseli', 'Tommy Smith', 'Bradley Robinson', 'David De Gea', 'Patrice Evra', 'Phil Jones', 'Rio Ferdinand', 'Jonny Evans', 'Michael Owen', 'Anderson', 'Dimitar Berbatov', 'Wayne Rooney', 'Ryan Giggs', 'Chris Smalling', 'Park Ji-Sung', 'Javier Hernández', 'Nemanja Vidić', 'Michael Carrick', 'Nani', 'Ash
 'Harry Kane', 'David Bentley', 'Ryan Fredericks', 'Cristian Ceballos', 'Massimo Luongo', 'Jake Nicholson', 'Adam Smith', 'Cameron Lancaster', 'Alex Pritchard', 'Jesse Waller-Lassen', 'Jordan Archer', 'Dean Parrett', 'Kevin Stewart', 'Jack Barthram', 'Wilson Palacios', 'Alan Hutton', 'Jermaine Jenas', 'Peter Crouch', 'Ryan Mason', 'Iago Falqué', 'John Bostock', 'Tom Carroll', 'Kudus Oyenuga', 'Vedran Ćorluka', 'Sébastien Bassong', 'Steven Pienaar', 'Roman Pavlyuchenko', 'Simon Dawkins', 'Ben Foster', 'Jonas Olsson', 'Somen Tchoyi', 'Liam Ridgewell', 'James Morrison', 'Keith Andrews', 'Shane Long', 'Chris Brunt', 'Steven Reid', 'Márton Fülöp', 'Jerome Thomas', 'Scott\xa0Allan', 'Graham Dorrans', 'Luke Daniels', 'Nicky Shorey', 'Youssouf Mulumbu', 'Zoltán Gera', 'Gareth McAuley', 'Peter Odemwingie', 'Craig Dawson', 'James Hurst', 'Sam Mantom', 'Billy Jones', 'George Thorne', 'Gabriel Tamaş', 'Simon Cox', 'Marc-Antoine Fortuné', 'Paul Scharner', 'Paul Downing', 'Romaine Sawyers', 'Adil Nabi', 'Kayelden Brown', 'Saido Berahino', 'Kemar Roofe', 'Lateef Elford-Alliyu', 'Cameron Gayle', 'Ishmael Miller', 'Marek Čech', 'Pablo', 'Chris Wood', 'Roman Bednář', 'Joe Mattock', 'Gonzalo Jara', "Liam O'Neil", 'Chris Kirkland', 'Steve Gohouri', 'Antolín Alcaraz', 'James McCarthy', 'Gary Caldwell', 'Hendry Thomas', 'Albert Crusat', 'Ben Watson', 'Franco Di Santo', 'Shaun Maloney', 'Victor Moses', 'Mike Pollitt', 'Lee Nicholls', 'Jordi Gómez', 'Callum McManaman', 'James McArthur', 'Emmerson Boyce', 'Conor Sammon', 'David Jones', 'Hugo Rodallega', 'Mohamed Diamé', 'Jean Beausejour', 'Ronnie Stam', 'Piscu', 'Ali Al-Habsi', 'Maynor Figueroa', 'Román Golobart', 'Patrick van Aanholt', 'Daniel Redmond', 'Nouha Dicko', 'Jordan Mustoe', 'Wayne Hennessey', 'George Elokobi', 'David Edwards', 'Richard Stearman', 'Jody Craddock', 'Michael Kightly', 'Karl Henry', 'Sylvan Ebanks-Blake', 'Steven Fletcher', 'Stephen Ward', 'Stephen Hunt', 'Carl Ikeme', 'Roger Johnson', 'Emmanuel Frimpong', 'Christophe Berra', 'Matthew Jarvis', 'Adam Hammill', 'Nenad Milijaš', 'Sébastien Bassong', 'Eggert Jónsson', 'Ronald Zubar', "Jamie O'Hara", 'David Davis', 'Kevin Doyle', 'Dorus de Vries', 'Kevin Foley', 'Jake Cassidy', 'Anthony Forde', 'Louis Harris', 'Michael Ihiekwe', 'Ashley Hemmings', 'Jack Price', 'James Spray', 'Jamie Reckord', 'Nathaniel Mendez-Laing', 'Aaron McCarey', 'Johnny Gorman', 'Ethan Ebanks-Landell', 'Stefan Maierhofer', 'Leigh Griffiths', 'Scott Malone', 'Sam Winnall', 'Sam Vokes', 'Adlène Guédioura', 'Andrew Keogh', 'Matt Doherty', 'Brian McGroary']

# %%
import time

df = pd.DataFrame(columns=['player_name', 'active', 'fyear', 'fclub'])

for i, player in enumerate(players[:5]):
  active, fyear, fclub, = get_status(player)
  df.loc[i] = [player, active, fyear, fclub]
  time.sleep(1)

df
# Out:
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Marseille in 2015–2017
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Montreal Impact in 2018–2019
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Arsenal in 2011–2018
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Vissel Kobe in 2019–2021
#         player_name  active      fyear            fclub
# 0    Manuel Almunia    True        n/a              n/a
# 1        Abou Diaby   False  2015–2017        Marseille
# 2      Bacary Sagna   False  2018–2019  Montreal Impact
# 3   Per Mertesacker   False  2011–2018          Arsenal
# 4  Thomas Vermaelen   False  2019–2021      Vissel Kobe

# %% [markdown]
# # **Conclusion**
# ## this worked OK
# * Data scraped for ~80% of players I searched for
# * 150 / 877 (~20%) failed to retreive useful data from wikiped
#
# ## so many players are still playing!!!
# * According to my search ~40% of all players active in 2011 are still playing
# and ~42% have retired
#
# ## Notable "still playings..."
# * Papiss Cisse
# * Asmir Begović
# * Juan Mata
# * Carlos Vela
#
# ##Bugs
# * If a player played their whole career for a single team, I marked them as active (Ryan Giggs and Tony Hibbert
# * Players with "common names" failed to retrieve records since its likely the URL was looking for additional information like David Davis (footballer) not David Davis (politician)

# %%
import time

df = pd.DataFrame(columns=['player_name', 'active', 'fyear', 'fclub'])

for i, player in enumerate(players):
  print("progress: {}/{}".format(i, len(players)))
  active, fyear, fclub, = get_status(player)
  df.loc[i] = [player, active, fyear, fclub]
  time.sleep(1)

df
# Out:
# progress: 0/877
# getting states for Manuel Almunia
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 1/877
# getting states for Abou Diaby
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Marseille in 2015–2017
# progress: 2/877
# getting states for Bacary Sagna
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Montreal Impact in 2018–2019
# progress: 3/877
# getting states for Per Mertesacker
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Arsenal in 2011–2018
# progress: 4/877
# getting states for Thomas Vermaelen
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Vissel Kobe in 2019–2021
# progress: 5/877
# getting states for Laurent Koscielny
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Bordeaux in 2019–2022
# progress: 6/877
# getting states for Tomáš Rosický
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Sparta Prague in 2016–2017
# progress: 7/877
# getting states for Mikel Arteta
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Arsenal in 2011–2016
# progress: 8/877
# getting states for Park Chu-Young
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Ulsan HD
# progress: 9/877
# getting states for Robin van Persie
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Feyenoord in 2018–2019
# progress: 10/877
# getting states for André Santos
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Figueirense in 2018
# progress: 11/877
# getting states for Wojciech Szczęsny
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Barcelona
# progress: 12/877
# getting states for Theo Walcott
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Southampton in 2021–2023
# progress: 13/877
# getting states for Alex Oxlade-Chamberlain
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Beşiktaş
# progress: 14/877
# getting states for Aaron Ramsey
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Cardiff City
# progress: 15/877
# getting states for Alexandre Song
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Arta/Solar7 in 2020–2023
# progress: 16/877
# getting states for Sébastien Squillaci
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Bastia in 2013–2017
# progress: 17/877
# getting states for Jack Wilshere
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for AGF in 2022
# progress: 18/877
# getting states for Johan Djourou
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Nordsjælland in 2020–2021
# progress: 19/877
# getting states for Łukasz Fabiański
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for West Ham United
# progress: 20/877
# getting states for Carl Jenkinson
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Bromley
# progress: 21/877
# getting states for Kouassi Gervais "Gervinho" Yao
# ERROR; Could not retrieve Wikipedia page
# progress: 22/877
# getting states for Kieran Gibbs
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Inter Miami II in 2022
# progress: 23/877
# getting states for Marouane Chamakh
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Cardiff City in 2016
# progress: 24/877
# getting states for Yossi Benayoun
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Beitar Jerusalem in 2019
# progress: 25/877
# getting states for Benik Afobe
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Mesaimeer
# progress: 26/877
# getting states for Zak Ansah
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Welling Town
# progress: 27/877
# getting states for George Brislen-Hall
# ERROR; Could not retrieve Wikipedia page
# progress: 28/877
# getting states for Francis Coquelin
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Villarreal
# progress: 29/877
# getting states for Craig Eastmond
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 30/877
# getting states for Sead Hajrovic
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Xamax
# progress: 31/877
# getting states for Conor Henderson
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Pirin Blagoevgrad
# progress: 32/877
# getting states for Gavin Hoyte
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Folkestone Invicta
# progress: 33/877
# getting states for Sean McDermott
# No infobox found
# ERROR; Could not parse infobox
# progress: 34/877
# getting states for Jernade Meade
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Tonbridge Angels
# progress: 35/877
# getting states for Ignasi Miquel
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Granada
# progress: 36/877
# getting states for Nigel Neita
# ERROR; Could not retrieve Wikipedia page
# progress: 37/877
# getting states for Oğuzhan Özyakup
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Fortuna Sittard
# progress: 38/877
# getting states for Nico Yennaris
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Beijing Guoan
# progress: 39/877
# getting states for Martin Angha
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Oțelul Galați
# progress: 40/877
# getting states for Kyle Ebecilio
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Capelle
# progress: 41/877
# getting states for Emiliano Martínez
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Aston Villa
# progress: 42/877
# getting states for Elton Monteiro
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Vevey-Sports
# progress: 43/877
# getting states for Josh Rees
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Dagenham & Redbridge
# progress: 44/877
# getting states for James Shea
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 45/877
# getting states for Cesc Fàbregas
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Como in 2022–2023
# progress: 46/877
# getting states for Carlos Vela
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Los Angeles FC
# progress: 47/877
# getting states for Samir Nasri
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Anderlecht in 2019–2020
# progress: 48/877
# getting states for Armand Traoré
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Cardiff City in 2019–2020
# progress: 49/877
# getting states for Henri Lansbury
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Luton Town in 2021–2023
# progress: 50/877
# getting states for Gilles Sunu
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Châteauroux B
# progress: 51/877
# getting states for Nicklas Bendtner
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Copenhagen in 2019
# progress: 52/877
# getting states for Emmanuel Frimpong
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Ermis Aradippou in 2017
# progress: 53/877
# getting states for Vito Mannone
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Lille
# progress: 54/877
# getting states for Luke Freeman
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Barnet
# progress: 55/877
# getting states for Chuks Aneke
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Charlton Athletic
# progress: 56/877
# getting states for Daniel Boateng
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 57/877
# getting states for Sanchez Watt
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Wealdstone
# progress: 58/877
# getting states for Rhys Murphy
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Dorking Wanderers
# progress: 59/877
# getting states for Ryo Miyaichi
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Yokohama F. Marinos
# progress: 60/877
# getting states for Thierry Henry
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for →Arsenal(loan) in 2012
# progress: 61/877
# getting states for Andrey Arshavin
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Kairat in 2016–2018
# progress: 62/877
# getting states for Shay Given
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Wyvern wanderers in 2015–2017
# progress: 63/877
# getting states for Alan Hutton
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for →Bolton Wanderers(loan) in 2014
# progress: 64/877
# getting states for Stephen Warnock
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for →Bradford City(loan) in 2018
# progress: 65/877
# getting states for Richard Dunne
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Queens Park Rangers in 2013–2015
# progress: 66/877
# getting states for James Collins
# No infobox found
# ERROR; Could not parse infobox
# progress: 67/877
# getting states for Stephen Ireland
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Bolton Wanderers in 2018
# progress: 68/877
# getting states for Jermaine Jenas
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Queens Park Rangers in 2013–2014
# progress: 69/877
# getting states for Darren Bent
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for →Burton Albion(loan) in 2018
# progress: 70/877
# getting states for Charles N'Zogbia
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Aston Villa in 2011–2016
# progress: 71/877
# getting states for Gabriel Agbonlahor
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for →Sheffield Wednesday(loan) in 2005
# progress: 72/877
# getting states for Marc Albrighton
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for →West Bromwich Albion(loan) in 2023
# progress: 73/877
# getting states for Nathan Delfouneso
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Hednesford Town
# progress: 74/877
# getting states for Fabian Delph
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Everton in 2019–2022
# progress: 75/877
# getting states for Emile Heskey
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Bolton Wanderers in 2014–2016
# progress: 76/877
# getting states for Stiliyan Petrov
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Aston Villa in 2006–2013
# progress: 77/877
# getting states for Ciaran Clark
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Stoke City
# progress: 78/877
# getting states for Brad Guzan
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Atlanta United
# progress: 79/877
# getting states for Carlos Cuéllar
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 80/877
# getting states for Barry Bannan
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Sheffield Wednesday
# progress: 81/877
# getting states for Andreas Weimann
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Blackburn Rovers
# progress: 82/877
# getting states for Enda Stevens
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Stoke City
# progress: 83/877
# getting states for Eric Lichaj
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Fatih Karagümrük in 2020–2021
# progress: 84/877
# getting states for Chris Herd
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Terengganu in 2021
# progress: 85/877
# getting states for Nathan Baker
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Bristol City in 2017–2022
# progress: 86/877
# getting states for Andy Marshall
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Millwall in 2013–2014
# progress: 87/877
# getting states for Daniel Johnson
# No infobox found
# ERROR; Could not parse infobox
# progress: 88/877
# getting states for Graham Burke
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Shamrock Rovers
# progress: 89/877
# getting states for Derrick Williams
# No infobox found
# ERROR; Could not parse infobox
# progress: 90/877
# getting states for Gary Gardner
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Cambridge United
# progress: 91/877
# getting states for Samir Carruthers
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Dartford
# progress: 92/877
# getting states for Jack Grealish
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Manchester City
# progress: 93/877
# getting states for Luke Young
# No infobox found
# ERROR; Could not parse infobox
# progress: 94/877
# getting states for Jonathan Hogg
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 95/877
# getting states for Jean II Makoun
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Merit Alsancak Yesilova SK in 2018–2020
# progress: 96/877
# getting states for Elliott Parish
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for St Johnstone
# progress: 97/877
# getting states for Shane Lowry
# No infobox found
# ERROR; Could not parse infobox
# progress: 98/877
# getting states for Habib Beye
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Doncaster Rovers in 2012
# progress: 99/877
# getting states for Robbie Keane
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for ATK in 2017–2018
# progress: 100/877
# getting states for Paul Robinson
# No infobox found
# ERROR; Could not parse infobox
# progress: 101/877
# getting states for Michel Salgado
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Independiente in 2018
# progress: 102/877
# getting states for Martin Olsson
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Malmö FF
# progress: 103/877
# getting states for Gaël Givet
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Tours in 2015–2016
# progress: 104/877
# getting states for David Dunn
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Oldham Athletic in 2015–2016
# progress: 105/877
# getting states for Anthony Modeste
# No infobox found
# ERROR; Could not parse infobox
# progress: 106/877
# getting states for Mauro Formica
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Defensores de Belgrano
# progress: 107/877
# getting states for Vince Grella
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Melbourne Heart in 2012–2013
# progress: 108/877
# getting states for Morten Gamst Pedersen
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Ranheim
# progress: 109/877
# getting states for Mark Bunn
# No infobox found
# ERROR; Could not parse infobox
# progress: 110/877
# getting states for Radosav Petrović
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for APOEL
# progress: 111/877
# getting states for Steven N'Zonzi
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Sepahan
# progress: 112/877
# getting states for Scott Dann
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Reading
# progress: 113/877
# getting states for Bradley Orr
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 114/877
# getting states for Jordan Slew
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Morecambe
# progress: 115/877
# getting states for Rubén Rochina
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Atlético Baleares
# progress: 116/877
# getting states for Marcus Olsson
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Halmstad
# progress: 117/877
# getting states for Nick Blackman
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Maccabi Tel Aviv
# progress: 118/877
# getting states for Junior Hoilett
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Hibernian
# progress: 119/877
# getting states for Yakubu Aiyegbeni
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Coventry City in 2017
# progress: 120/877
# getting states for David Goodwillie
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Glasgow United
# progress: 121/877
# getting states for Hérold Goulon
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Negeri Sembilan
# progress: 122/877
# getting states for Simon Vukčević
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Budućnost in 2018
# progress: 123/877
# getting states for Anthony O'Connor
# No infobox found
# ERROR; Could not parse infobox
# progress: 124/877
# getting states for Grant Hanley
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Norwich City
# progress: 125/877
# getting states for Bruno Ribeiro
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for →Chaves(loan) in 2009
# progress: 126/877
# getting states for Josh Morris
# No infobox found
# ERROR; Could not parse infobox
# progress: 127/877
# getting states for Jake Kean
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Notts County in 2019–2021
# progress: 128/877
# getting states for Jason Lowe
# No infobox found
# ERROR; Could not parse infobox
# progress: 129/877
# getting states for Amine Linganzi
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Salford City
# progress: 130/877
# getting states for Zac Aley
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 131/877
# getting states for Myles Anderson
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 132/877
# getting states for Adam Henley
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Chorley
# progress: 133/877
# getting states for Robbie Cotton
# ERROR; Could not retrieve Wikipedia page
# progress: 134/877
# getting states for Raheem Hanley
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for West Didsbury & Chorlton
# progress: 135/877
# getting states for Sebastian Usai
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 136/877
# getting states for Brett Emerton
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Sydney FC in 2011–2014
# progress: 137/877
# getting states for Jason Roberts
# No infobox found
# ERROR; Could not parse infobox
# progress: 138/877
# getting states for Keith Andrews
# No infobox found
# ERROR; Could not parse infobox
# progress: 139/877
# getting states for Ryan Nelsen
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Queens Park Rangers in 2012–2013
# progress: 140/877
# getting states for Christopher Samba
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Aston Villa in 2017–2018
# progress: 141/877
# getting states for Ádám Bogdán
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Ferencváros
# progress: 142/877
# getting states for Grétar Steinsson
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Kayserispor in 2012–2013
# progress: 143/877
# getting states for Marcos Alonso
# No infobox found
# ERROR; Could not parse infobox
# progress: 144/877
# getting states for Paul Robinson
# No infobox found
# ERROR; Could not parse infobox
# progress: 145/877
# getting states for Fabrice Muamba
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Bolton Wanderers in 2008–2012
# progress: 146/877
# getting states for Chris Eagles
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 147/877
# getting states for Stuart Holden
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for →Sheffield Wednesday(loan) in 2013
# progress: 148/877
# getting states for Tuncay Şanlı
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Pune City in 2015
# progress: 149/877
# getting states for Martin Petrov
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for CSKA Sofia in 2013–2014
# progress: 150/877
# getting states for Ricardo Gardner
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for →Preston North End(loan) in 2011
# progress: 151/877
# getting states for Zat Knight
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Reading in 2015
# progress: 152/877
# getting states for Kevin Davies
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Preston North End in 2013–2015
# progress: 153/877
# getting states for Tyrone Mears
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for West Bromwich Albion in 2018–2019
# progress: 154/877
# getting states for Mark Davies
# No infobox found
# ERROR; Could not parse infobox
# progress: 155/877
# getting states for Ivan Klasnić
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Mainz 05 in 2012–2013
# progress: 156/877
# getting states for Sam Ricketts
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Coventry City in 2015–2016
# progress: 157/877
# getting states for Nigel Reo-Coker
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Milton Keynes Dons in 2018
# progress: 158/877
# getting states for Robbie Blake
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Team Northumbria in 2013
# progress: 159/877
# getting states for Darren Pratley
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 160/877
# getting states for Jussi Jääskeläinen
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for ATK in 2017–2018
# progress: 161/877
# getting states for Sean Davis
# No infobox found
# ERROR; Could not parse infobox
# progress: 162/877
# getting states for David N'Gog
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Panionios
# progress: 163/877
# getting states for Dedryck Boyata
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Club Brugge
# progress: 164/877
# getting states for Robert Lainton
# ERROR; Could not retrieve Wikipedia page
# progress: 165/877
# getting states for Lee Chung-Yong
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Ulsan HD
# progress: 166/877
# getting states for Marvin Sordell
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Kettering Town
# progress: 167/877
# getting states for Ryo Miyaichi
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Yokohama F. Marinos
# progress: 168/877
# getting states for David Wheater
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Darlington in 2022–2023
# progress: 169/877
# getting states for Tim Ream
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Charlotte FC
# progress: 170/877
# getting states for Mark Connolly
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Derry City
# progress: 171/877
# getting states for Tom Eaves
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 172/877
# getting states for Temitope Obadeyi
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Kidderminster Harriers
# progress: 173/877
# getting states for Michael O'Halloran
# No infobox found
# ERROR; Could not parse infobox
# progress: 174/877
# getting states for Josh Vela
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 175/877
# getting states for Adam Blakeman
# No infobox found
# ERROR; Could not parse infobox
# progress: 176/877
# getting states for Joe Riley
# No infobox found
# ERROR; Could not parse infobox
# progress: 177/877
# getting states for Jay Lynch
# No infobox found
# ERROR; Could not parse infobox
# progress: 178/877
# getting states for Gaël Kakuta
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Esteghlal
# progress: 179/877
# getting states for Gary Cahill
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for AFC Bournemouth in 2021–2022
# progress: 180/877
# getting states for Petr Čech
# No infobox found
# ERROR; Could not parse infobox
# progress: 181/877
# getting states for Branislav Ivanović
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for West Bromwich Albion in 2020–2021
# progress: 182/877
# getting states for Ashley Cole
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Derby County in 2019
# progress: 183/877
# getting states for David Luiz
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Flamengo
# progress: 184/877
# getting states for Michael Essien
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Sabail in 2019–2020
# progress: 185/877
# getting states for Oriol Romeu
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for →Girona(loan)
# progress: 186/877
# getting states for Ramires
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Palmeiras in 2019–2020
# progress: 187/877
# getting states for Frank Lampard
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for New York City FC in 2015–2016
# progress: 188/877
# getting states for Fernando Torres
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Sagan Tosu in 2018–2019
# progress: 189/877
# getting states for Juan Mata
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Western Sydney Wanderers
# progress: 190/877
# getting states for Didier Drogba
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Phoenix Rising in 2017–2018
# progress: 191/877
# getting states for Mikel John Obi
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Kuwait SC in 2021
# progress: 192/877
# getting states for Florent Malouda
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for FC Differdange 03 in 2018
# progress: 193/877
# getting states for Raul Meireles
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Fenerbahçe in 2012–2016
# progress: 194/877
# getting states for José Bosingwa
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Trabzonspor in 2016
# progress: 195/877
# getting states for Romelu Lukaku
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Napoli
# progress: 196/877
# getting states for Paulo Ferreira
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Chelsea in 2004–2013
# progress: 197/877
# getting states for Salomon Kalou
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Arta/Solar7 in 2022–2024
# progress: 198/877
# getting states for Ross Turnbull
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Leeds United in 2015–2017
# progress: 199/877
# getting states for Daniel Sturridge
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Perth Glory in 2021–2022
# progress: 200/877
# getting states for Gary Cahill
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for AFC Bournemouth in 2021–2022
# progress: 201/877
# getting states for John Terry
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Aston Villa in 2017–2018
# progress: 202/877
# getting states for Sam Hutchinson
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Reading
# progress: 203/877
# getting states for Ryan Bertrand
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Leicester City in 2021–2023
# progress: 204/877
# getting states for Lucas Piazón
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for AVS
# progress: 205/877
# getting states for Hilário
# No infobox found
# ERROR; Could not parse infobox
# progress: 206/877
# getting states for Nathaniel
# 	Chalobah
# ERROR; Could not retrieve Wikipedia page
# progress: 207/877
# getting states for Jamal Blackman
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Burton Albion
# progress: 208/877
# getting states for Billy Clifford
# No infobox found
# ERROR; Could not parse infobox
# progress: 209/877
# getting states for Conor Clifford
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Bray Wanderers
# progress: 210/877
# getting states for Aziz Deen-Conteh
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Dulwich Hamlet in 2018
# progress: 211/877
# getting states for Rohan Ince
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Woking
# progress: 212/877
# getting states for Marko Mitrović
# No infobox found
# ERROR; Could not parse infobox
# progress: 213/877
# getting states for Todd Kane
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Ebbsfleet United
# progress: 214/877
# getting states for James Ashton
# No infobox found
# ERROR; Could not parse infobox
# progress: 215/877
# getting states for George Saville
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Millwall
# progress: 216/877
# getting states for Archange Nkumu
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 217/877
# getting states for Daniel Pappoe
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Roffey
# progress: 218/877
# getting states for Rhys Taylor
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Bradford (Park Avenue) in 2019
# progress: 219/877
# getting states for Yossi Benayoun
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Beitar Jerusalem in 2019
# progress: 220/877
# getting states for Yossi Benayoun
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Beitar Jerusalem in 2019
# progress: 221/877
# getting states for Nicolas Anelka
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Mumbai City in 2014–2015
# progress: 222/877
# getting states for Gaël Kakuta
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Esteghlal
# progress: 223/877
# getting states for Josh McEachran
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Oxford United
# progress: 224/877
# getting states for Patrick van Aanholt
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for →PSV(loan)
# progress: 225/877
# getting states for Alex
# No infobox found
# ERROR; Could not parse infobox
# progress: 226/877
# getting states for Aliu Djaló
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Pedras Rubras
# progress: 227/877
# getting states for Philipp Prosenik
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for SC Himberg
# progress: 228/877
# getting states for Jacob Mellis
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Leatherhead in 2022
# progress: 229/877
# getting states for Ján Mucha
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Hamilton Academical
# progress: 230/877
# getting states for Tony Hibbert
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 231/877
# getting states for Leighton Baines
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Everton in 2007–2020
# progress: 232/877
# getting states for Darron Gibson
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Salford City in 2020–2021
# progress: 233/877
# getting states for John Heitinga
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Ajax in 2015–2016
# progress: 234/877
# getting states for Phil Jagielka
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Stoke City in 2022–2023
# progress: 235/877
# getting states for Nikica Jelavić
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Lokomotiva in 2020–2021
# progress: 236/877
# getting states for Royston Drenthe
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Kozakken Boys in 2023
# progress: 237/877
# getting states for Denis Stracqualursi
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 238/877
# getting states for Marcus Hahnemann
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Seattle Sounders FC in 2012–2014
# progress: 239/877
# getting states for James McFadden
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Queen of the South in 2017–2018
# progress: 240/877
# getting states for Sylvain Distin
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 241/877
# getting states for Tim Cahill
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Jamshedpur in 2018–2019
# progress: 242/877
# getting states for Phil Neville
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Everton in 2005–2013
# progress: 243/877
# getting states for Magaye Gueye
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Anagennisi Karditsa
# progress: 244/877
# getting states for Ross Barkley
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Aston Villa
# progress: 245/877
# getting states for Leon Osman
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for →Derby County(loan) in 2004
# progress: 246/877
# getting states for Steven Pienaar
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Bidvest Wits in 2017–2018
# progress: 247/877
# getting states for Séamus Coleman
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for →Blackpool(loan)
# progress: 248/877
# getting states for Tim Howard
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Memphis 901 in 2020
# progress: 249/877
# getting states for Marouane Fellaini
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Shandong Taishan in 2019–2024
# progress: 250/877
# getting states for Jack Rodwell
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Sydney FC
# progress: 251/877
# getting states for Apostolos Vellios
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Nea Salamis Famagusta
# progress: 252/877
# getting states for Victor Anichebe
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Beijing Enterprises Group in 2017
# progress: 253/877
# getting states for João Silva
# No infobox found
# ERROR; Could not parse infobox
# progress: 254/877
# getting states for Francisco Júnior
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Botoșani
# progress: 255/877
# getting states for Adam Forshaw
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 256/877
# getting states for Shane Duffy
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Norwich City
# progress: 257/877
# getting states for Aristote Nsiala
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Shrewsbury Town
# progress: 258/877
# getting states for Jose Baxter
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Memphis 901 in 2020
# progress: 259/877
# getting states for James Wallace
# No infobox found
# ERROR; Could not parse infobox
# progress: 260/877
# getting states for Adam Davies
# No infobox found
# ERROR; Could not parse infobox
# progress: 261/877
# getting states for Jake Bidwell
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Coventry City
# progress: 262/877
# getting states for Luke Garbutt
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Salford City
# progress: 263/877
# getting states for Conor McAleny
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 264/877
# getting states for Femi Orenuga
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 265/877
# getting states for Mikel Arteta
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Arsenal in 2011–2016
# progress: 266/877
# getting states for Jermaine Beckford
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Bury in 2017–2019
# progress: 267/877
# getting states for Yakubu Aiyegbeni
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Coventry City in 2017
# progress: 268/877
# getting states for Joseph Yobo
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for →Norwich City(loan) in 2014
# progress: 269/877
# getting states for Shkodran Mustafi
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Levante in 2021–2023
# progress: 270/877
# getting states for Diniyar Bilyaletdinov
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Trakai in 2017–2018
# progress: 271/877
# getting states for Louis Saha
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Lazio in 2013
# progress: 272/877
# getting states for Landon Donovan
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for San Diego Sockers(indoor) in 2018–2019
# progress: 273/877
# getting states for Mark Schwarzer
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Leicester City in 2015–2016
# progress: 274/877
# getting states for Stephen Kelly
# No infobox found
# ERROR; Could not parse infobox
# progress: 275/877
# getting states for John Arne Riise
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Avaldsnes in 2023
# progress: 276/877
# getting states for Steve Sidwell
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Brighton & Hove Albion in 2016–2018
# progress: 277/877
# getting states for Brede Hangeland
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Crystal Palace in 2014–2016
# progress: 278/877
# getting states for Chris Baird
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for →Fulham(loan) in 2016
# progress: 279/877
# getting states for Pavel Pogrebnyak
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Ural Yekaterinburg
# progress: 280/877
# getting states for Andy Johnson
# No infobox found
# ERROR; Could not parse infobox
# progress: 281/877
# getting states for Orlando Sá
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Málaga in 2020–2021
# progress: 282/877
# getting states for Pajtim Kasami
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Sampdoria
# progress: 283/877
# getting states for Bryan Ruiz
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Alajuelense in 2020–2022
# progress: 284/877
# getting states for David Stockdale
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for York City
# progress: 285/877
# getting states for Danny Murphy
# No infobox found
# ERROR; Could not parse infobox
# progress: 286/877
# getting states for Philippe Senderos
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Chiasso in 2019
# progress: 287/877
# getting states for Marcel Gecov
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Śląsk Wrocław in 2015–2016
# progress: 288/877
# getting states for Damien Duff
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Shamrock Rovers in 2015
# progress: 289/877
# getting states for Bjørn Helge Riise
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Stabæk 2 in 2023
# progress: 290/877
# getting states for Aaron Hughes
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Heart of Midlothian in 2017–2019
# progress: 291/877
# getting states for Mahamadou Diarra
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Fulham in 2012–2014
# progress: 292/877
# getting states for Dickson Etuhu
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for IFK Rössjöholm in 2017
# progress: 293/877
# getting states for Kerim Frei
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Elazığspor
# progress: 294/877
# getting states for Csaba Somogyi
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 295/877
# getting states for Clint Dempsey
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for →Fulham(loan) in 2014
# progress: 296/877
# getting states for Lauri Dalla Valle
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Zemun in 2017
# progress: 297/877
# getting states for Zdeněk Grygera
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Fulham in 2011–2012
# progress: 298/877
# getting states for Matthew Briggs
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Horsham in 2023
# progress: 299/877
# getting states for Simon Davies
# No infobox found
# ERROR; Could not parse infobox
# progress: 300/877
# getting states for Mousa Dembélé
# No infobox found
# ERROR; Could not parse infobox
# progress: 301/877
# getting states for Alex Kačaniklić
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for AEL Limassol
# progress: 302/877
# getting states for Rafik Halliche
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Moreirense
# progress: 303/877
# ...
# progress: 774/877
# getting states for Craig Dawson
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Wolverhampton Wanderers
# progress: 775/877
# getting states for James Hurst
# No infobox found
# ERROR; Could not parse infobox
# progress: 776/877
# getting states for Sam Mantom
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Rushall Olympic
# progress: 777/877
# getting states for Billy Jones
# No infobox found
# ERROR; Could not parse infobox
# progress: 778/877
# getting states for George Thorne
# No infobox found
# ERROR; Could not parse infobox
# progress: 779/877
# getting states for Gabriel Tamaş
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Concordia Chiajna in 2023
# progress: 780/877
# getting states for Simon Cox
# No infobox found
# ERROR; Could not parse infobox
# progress: 781/877
# getting states for Marc-Antoine Fortuné
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for La Louvière Centre in 2020–2021
# progress: 782/877
# getting states for Paul Scharner
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for →Wigan Athletic(loan) in 2013
# progress: 783/877
# getting states for Paul Downing
# No infobox found
# ERROR; Could not parse infobox
# progress: 784/877
# getting states for Romaine Sawyers
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Cardiff City
# progress: 785/877
# getting states for Adil Nabi
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Doxa Katokopias
# progress: 786/877
# getting states for Kayelden Brown
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Stourbridge
# progress: 787/877
# getting states for Saido Berahino
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Rajasthan United
# progress: 788/877
# getting states for Kemar Roofe
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Rangers
# progress: 789/877
# getting states for Lateef Elford-Alliyu
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Coventry City
# progress: 790/877
# getting states for Cameron Gayle
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 791/877
# getting states for Ishmael Miller
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 792/877
# getting states for Marek Čech
# No infobox found
# ERROR; Could not parse infobox
# progress: 793/877
# getting states for Pablo
# No infobox found
# ERROR; Could not parse infobox
# progress: 794/877
# getting states for Chris Wood
# No infobox found
# ERROR; Could not parse infobox
# progress: 795/877
# getting states for Roman Bednář
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Příbram in 2015–2016
# progress: 796/877
# getting states for Joe Mattock
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Marine
# progress: 797/877
# getting states for Gonzalo Jara
# No infobox found
# ERROR; Could not parse infobox
# progress: 798/877
# getting states for Liam O'Neil
# No infobox found
# ERROR; Could not parse infobox
# progress: 799/877
# getting states for Chris Kirkland
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Bury in 2016
# progress: 800/877
# getting states for Steve Gohouri
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for TSV Steinbach in 2015
# progress: 801/877
# getting states for Antolín Alcaraz
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Olimpia
# progress: 802/877
# getting states for James McCarthy
# No infobox found
# ERROR; Could not parse infobox
# progress: 803/877
# getting states for Gary Caldwell
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Wigan Athletic in 2010–2015
# progress: 804/877
# getting states for Hendry Thomas
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Olimpia in 2018–2019
# progress: 805/877
# getting states for Albert Crusat
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Bnei Sakhnin in 2014
# progress: 806/877
# getting states for Ben Watson
# No infobox found
# ERROR; Could not parse infobox
# progress: 807/877
# getting states for Franco Di Santo
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Independiente Rivadavia
# progress: 808/877
# getting states for Shaun Maloney
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Hull City in 2015–2017
# progress: 809/877
# getting states for Victor Moses
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Luton Town
# progress: 810/877
# getting states for Mike Pollitt
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 811/877
# getting states for Lee Nicholls
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Huddersfield Town
# progress: 812/877
# getting states for Jordi Gómez
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Omonia 29M
# progress: 813/877
# getting states for Callum McManaman
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Wigan Athletic
# progress: 814/877
# getting states for James McArthur
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Crystal Palace in 2014–2023
# progress: 815/877
# getting states for Emmerson Boyce
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Ashton Town in 2020
# progress: 816/877
# getting states for Conor Sammon
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Alloa Athletic
# progress: 817/877
# getting states for David Jones
# No infobox found
# ERROR; Could not parse infobox
# progress: 818/877
# getting states for Hugo Rodallega
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Santa Fe
# progress: 819/877
# getting states for Mohamed Diamé
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Al-Sailiya
# progress: 820/877
# getting states for Jean Beausejour
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Coquimbo Unido in 2021
# progress: 821/877
# getting states for Ronnie Stam
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 822/877
# getting states for Piscu
# No infobox found
# ERROR; Could not parse infobox
# progress: 823/877
# getting states for Ali Al-Habsi
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for West Bromwich Albion in 2019–2020
# progress: 824/877
# getting states for Maynor Figueroa
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Houston Dynamo in 2019–2021
# progress: 825/877
# getting states for Román Golobart
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Nea Salamina
# progress: 826/877
# getting states for Patrick van Aanholt
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for →PSV(loan)
# progress: 827/877
# getting states for Daniel Redmond
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 828/877
# getting states for Nouha Dicko
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Paris FC
# progress: 829/877
# getting states for Jordan Mustoe
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 830/877
# getting states for Wayne Hennessey
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Nottingham Forest
# progress: 831/877
# getting states for George Elokobi
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Maidstone United in 2019–2022
# progress: 832/877
# getting states for David Edwards
# No infobox found
# ERROR; Could not parse infobox
# progress: 833/877
# getting states for Richard Stearman
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Solihull Moors in 2023–2024
# progress: 834/877
# getting states for Jody Craddock
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 835/877
# getting states for Michael Kightly
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Rushall Olympic in 2020–2021
# progress: 836/877
# getting states for Karl Henry
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Boldmere St. Michaels in 2023–
# progress: 837/877
# getting states for Sylvan Ebanks-Blake
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Walsall Wood in 2018–2019
# progress: 838/877
# getting states for Steven Fletcher
# No infobox found
# ERROR; Could not parse infobox
# progress: 839/877
# getting states for Stephen Ward
# No infobox found
# ERROR; Could not parse infobox
# progress: 840/877
# getting states for Stephen Hunt
# No infobox found
# ERROR; Could not parse infobox
# progress: 841/877
# getting states for Carl Ikeme
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for →Doncaster Rovers(loan) in 2012
# progress: 842/877
# getting states for Roger Johnson
# No infobox found
# ERROR; Could not parse infobox
# progress: 843/877
# getting states for Emmanuel Frimpong
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Ermis Aradippou in 2017
# progress: 844/877
# getting states for Christophe Berra
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Raith Rovers in 2021–2022
# progress: 845/877
# getting states for Matthew Jarvis
# No infobox found
# ERROR; Could not parse infobox
# progress: 846/877
# getting states for Adam Hammill
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Maghull in 2023–
# progress: 847/877
# getting states for Nenad Milijaš
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Red Star Belgrade in 2017–2019
# progress: 848/877
# getting states for Sébastien Bassong
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Volos in 2019
# progress: 849/877
# getting states for Eggert Jónsson
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Austfjarða
# progress: 850/877
# getting states for Ronald Zubar
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Red Star in 2017
# progress: 851/877
# getting states for Jamie O'Hara
# No infobox found
# ERROR; Could not parse infobox
# progress: 852/877
# getting states for David Davis
# No infobox found
# ERROR; Could not parse infobox
# progress: 853/877
# getting states for Kevin Doyle
# Successfully parsed infobox
# Successfully retrieved status; Player not playing, last played for Colorado Rapids in 2015–2017
# progress: 854/877
# getting states for Dorus de Vries
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 855/877
# getting states for Kevin Foley
# No infobox found
# ERROR; Could not parse infobox
# progress: 856/877
# getting states for Jake Cassidy
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Silsden
# progress: 857/877
# getting states for Anthony Forde
# No infobox found
# ERROR; Could not parse infobox
# progress: 858/877
# getting states for Louis Harris
# No infobox found
# ERROR; Could not parse infobox
# progress: 859/877
# getting states for Michael Ihiekwe
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 860/877
# getting states for Ashley Hemmings
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Kidderminster Harriers
# progress: 861/877
# getting states for Jack Price
# No infobox found
# ERROR; Could not parse infobox
# progress: 862/877
# getting states for James Spray
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 863/877
# getting states for Jamie Reckord
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Gloucester City
# progress: 864/877
# getting states for Nathaniel Mendez-Laing
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Derby County
# progress: 865/877
# getting states for Aaron McCarey
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Portadown
# progress: 866/877
# getting states for Johnny Gorman
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Frome Town
# progress: 867/877
# getting states for Ethan Ebanks-Landell
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 868/877
# getting states for Stefan Maierhofer
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Würzburger Kickers
# progress: 869/877
# getting states for Leigh Griffiths
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Mandurah City
# progress: 870/877
# getting states for Scott Malone
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Crawley Town
# progress: 871/877
# getting states for Sam Winnall
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for None
# progress: 872/877
# getting states for Sam Vokes
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for Wycombe Wanderers
# progress: 873/877
# getting states for Adlène Guédioura
# Successfully parsed infobox
# Successfully retrieved status; Player still playing, currently playing for CR Belouizdad
# progress: 874/877
# getting states for Andrew Keogh
# No infobox found
# ERROR; Could not parse infobox
# progress: 875/877
# getting states for Matt Doherty
# No infobox found
# ERROR; Could not parse infobox
# progress: 876/877
# getting states for Brian McGroary
# ERROR; Could not retrieve Wikipedia page
#           player_name active      fyear            fclub
# 0      Manuel Almunia   True        n/a              n/a
# 1          Abou Diaby  False  2015–2017        Marseille
# 2        Bacary Sagna  False  2018–2019  Montreal Impact
# 3     Per Mertesacker  False  2011–2018          Arsenal
# 4    Thomas Vermaelen  False  2019–2021      Vissel Kobe
# ..                ...    ...        ...              ...
# 872         Sam Vokes   True        n/a              n/a
# 873  Adlène Guédioura   True        n/a              n/a
# 874      Andrew Keogh    n/a        n/a              n/a
# 875      Matt Doherty    n/a        n/a              n/a
# 876    Brian McGroary    n/a        n/a              n/a
#
# [877 rows x 4 columns]
